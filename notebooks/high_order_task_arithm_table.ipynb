# %%
approaches = ["TA", "TIES", "BC", "HOTA"]
orders = [2, 4, 7, 10]
results = {approach: {} for approach in approaches}

datasets = ["CIFAR100", "DTD", "EuroSAT", "GTSRB", "MNIST", "RESISC45", "SVHN"]

columns = datasets + ["average"]

# %%
results["TA"][2] = {
    "CIFAR100": [
        {
            "acc/test": 0.5845999717712402,
            "loss/test": 1.6968116760253906,
            "sparsity/test": 77.10091400146484,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.39007091522216797,
            "loss/test": 2.511599540710449,
            "sparsity/test": 77.1006851196289,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7757407426834106,
            "loss/test": 0.7313326597213745,
            "sparsity/test": 77.10126495361328,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.5937450528144836,
            "loss/test": 1.4191186428070068,
            "sparsity/test": 77.10104370117188,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9807000160217285,
            "loss/test": 0.1356048732995987,
            "sparsity/test": 77.10091400146484,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.5768253803253174,
            "loss/test": 1.512149691581726,
            "sparsity/test": 77.1006088256836,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8331284523010254,
            "loss/test": 0.6382136940956116,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["TA"][4] = {
    "CIFAR100": [
        {
            "acc/test": 0.7134000062942505,
            "loss/test": 1.0436620712280273,
            "sparsity/test": 77.10027313232422,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.48049646615982056,
            "loss/test": 1.9212076663970947,
            "sparsity/test": 77.10057830810547,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.8017592430114746,
            "loss/test": 0.661742091178894,
            "sparsity/test": 77.10063934326172,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.6207442879676819,
            "loss/test": 1.2338221073150635,
            "sparsity/test": 77.10013580322266,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9692999720573425,
            "loss/test": 0.22053362429141998,
            "sparsity/test": 77.10027313232422,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.7061904668807983,
            "loss/test": 0.9364738464355469,
            "sparsity/test": 77.10057830810547,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8243700265884399,
            "loss/test": 0.6650741696357727,
            "sparsity/test": 77.10079193115234,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["TA"][7] = {
    "CIFAR100": [
        {
            "acc/test": 0.6689000129699707,
            "loss/test": 1.269337773323059,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.43528369069099426,
            "loss/test": 2.1681227684020996,
            "sparsity/test": 77.1006088256836,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7916203737258911,
            "loss/test": 0.6808181405067444,
            "sparsity/test": 77.10125732421875,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.6178147196769714,
            "loss/test": 1.3051279783248901,
            "sparsity/test": 77.10103607177734,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9717000126838684,
            "loss/test": 0.17793892323970795,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.6666666865348816,
            "loss/test": 1.1155586242675781,
            "sparsity/test": 77.10059356689453,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8309388160705566,
            "loss/test": 0.6309589147567749,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["TA"][10] = {
    "CIFAR100": [
        {
            "acc/test": 0.6341999769210815,
            "loss/test": 1.4691473245620728,
            "sparsity/test": 77.10091400146484,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.4104609787464142,
            "loss/test": 2.3780295848846436,
            "sparsity/test": 77.10067749023438,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7626388669013977,
            "loss/test": 0.7725141048431396,
            "sparsity/test": 77.10126495361328,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.6302454471588135,
            "loss/test": 1.2631511688232422,
            "sparsity/test": 77.10104370117188,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.968999981880188,
            "loss/test": 0.1677020788192749,
            "sparsity/test": 77.10091400146484,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.6163492202758789,
            "loss/test": 1.3767493963241577,
            "sparsity/test": 77.1006088256836,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8298632502555847,
            "loss/test": 0.6302403211593628,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}

results["TIES"][2] = {
    "CIFAR100": [
        {
            "acc/test": 0.7572000026702881,
            "loss/test": 0.8784485459327698,
            "sparsity/test": 58.3643684387207,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.4556737542152405,
            "loss/test": 2.0481204986572266,
            "sparsity/test": 58.36435317993164,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7081481218338013,
            "loss/test": 0.939332127571106,
            "sparsity/test": 58.36450958251953,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.5479018092155457,
            "loss/test": 1.5386537313461304,
            "sparsity/test": 58.36454772949219,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.95660001039505,
            "loss/test": 0.34625211358070374,
            "sparsity/test": 58.3643684387207,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.705396831035614,
            "loss/test": 0.931323766708374,
            "sparsity/test": 58.36427688598633,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8101951479911804,
            "loss/test": 0.7324383854866028,
            "sparsity/test": 58.36429977416992,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["TIES"][4] = {
    "CIFAR100": [
        {
            "acc/test": 0.745199978351593,
            "loss/test": 0.9241610169410706,
            "sparsity/test": 58.5468864440918,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.44946807622909546,
            "loss/test": 2.13678240776062,
            "sparsity/test": 58.5469856262207,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.6878240704536438,
            "loss/test": 1.014892339706421,
            "sparsity/test": 58.54688262939453,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.5562153458595276,
            "loss/test": 1.5029000043869019,
            "sparsity/test": 58.5468864440918,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9661999940872192,
            "loss/test": 0.24786992371082306,
            "sparsity/test": 58.5468864440918,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.6887301802635193,
            "loss/test": 0.9984086155891418,
            "sparsity/test": 58.54689407348633,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8359711170196533,
            "loss/test": 0.6296728253364563,
            "sparsity/test": 58.546878814697266,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["TIES"][7] = {
    "CIFAR100": [
        {
            "acc/test": 0.7210000157356262,
            "loss/test": 1.0338226556777954,
            "sparsity/test": 58.711151123046875,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.43262410163879395,
            "loss/test": 2.2111704349517822,
            "sparsity/test": 58.711387634277344,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.6628703474998474,
            "loss/test": 1.0638386011123657,
            "sparsity/test": 58.711036682128906,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.5581947565078735,
            "loss/test": 1.485528588294983,
            "sparsity/test": 58.71110534667969,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9696000218391418,
            "loss/test": 0.20071479678153992,
            "sparsity/test": 58.711151123046875,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.6614285707473755,
            "loss/test": 1.1088021993637085,
            "sparsity/test": 58.711273193359375,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8459972143173218,
            "loss/test": 0.5815761685371399,
            "sparsity/test": 58.71101760864258,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["TIES"][10] = {
    "CIFAR100": [
        {
            "acc/test": 0.675000011920929,
            "loss/test": 1.2425940036773682,
            "sparsity/test": 66.2513656616211,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.408687949180603,
            "loss/test": 2.3616600036621094,
            "sparsity/test": 66.25143432617188,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.698379635810852,
            "loss/test": 0.9845686554908752,
            "sparsity/test": 66.25115966796875,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.5615993738174438,
            "loss/test": 1.4726002216339111,
            "sparsity/test": 66.2514877319336,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9801999926567078,
            "loss/test": 0.14284147322177887,
            "sparsity/test": 66.2513656616211,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.6198412775993347,
            "loss/test": 1.2683476209640503,
            "sparsity/test": 66.25128173828125,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8551398515701294,
            "loss/test": 0.5596340298652649,
            "sparsity/test": 66.25096893310547,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}

results["BC"][2] = {
    "CIFAR100": [
        {
            "acc/test": 0.7156999707221985,
            "loss/test": 1.0262783765792847,
            "sparsity/test": 77.10026550292969,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.4760638177394867,
            "loss/test": 1.924914002418518,
            "sparsity/test": 77.10051727294922,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7959722280502319,
            "loss/test": 0.6796671748161316,
            "sparsity/test": 77.10063934326172,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.6112430691719055,
            "loss/test": 1.2640198469161987,
            "sparsity/test": 77.10012817382812,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.965399980545044,
            "loss/test": 0.2517310678958893,
            "sparsity/test": 77.10026550292969,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.7031745910644531,
            "loss/test": 0.9423171877861023,
            "sparsity/test": 77.10057067871094,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.807429313659668,
            "loss/test": 0.7230935096740723,
            "sparsity/test": 77.10079193115234,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["BC"][4] = {
    "CIFAR100": [
        {
            "acc/test": 0.6787999868392944,
            "loss/test": 1.2219518423080444,
            "sparsity/test": 77.10027313232422,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.43262410163879395,
            "loss/test": 2.146019697189331,
            "sparsity/test": 77.10057830810547,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7876851558685303,
            "loss/test": 0.6914772987365723,
            "sparsity/test": 77.10063934326172,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.6093428134918213,
            "loss/test": 1.325383186340332,
            "sparsity/test": 77.10013580322266,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9685999751091003,
            "loss/test": 0.2042163759469986,
            "sparsity/test": 77.10027313232422,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.666190505027771,
            "loss/test": 1.106410026550293,
            "sparsity/test": 77.10057830810547,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8131530284881592,
            "loss/test": 0.6913499236106873,
            "sparsity/test": 77.10079193115234,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["BC"][7] = {
    "CIFAR100": [
        {
            "acc/test": 0.6474999785423279,
            "loss/test": 1.396722674369812,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.4131205677986145,
            "loss/test": 2.3316075801849365,
            "sparsity/test": 77.1006088256836,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7624536752700806,
            "loss/test": 0.7684956192970276,
            "sparsity/test": 77.10125732421875,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.6166270971298218,
            "loss/test": 1.2845488786697388,
            "sparsity/test": 77.10103607177734,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9656999707221985,
            "loss/test": 0.1924682855606079,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.6190476417541504,
            "loss/test": 1.3440974950790405,
            "sparsity/test": 77.10059356689453,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8085817694664001,
            "loss/test": 0.6945872902870178,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["BC"][10] = {
    "CIFAR100": [
        {
            "acc/test": 0.6031000018119812,
            "loss/test": 1.6014925241470337,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.3989361822605133,
            "loss/test": 2.444425344467163,
            "sparsity/test": 77.1006088256836,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.7774537205696106,
            "loss/test": 0.7277599573135376,
            "sparsity/test": 77.10125732421875,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.5849564671516418,
            "loss/test": 1.4260894060134888,
            "sparsity/test": 77.10103607177734,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9775999784469604,
            "loss/test": 0.1569979190826416,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.5861904621124268,
            "loss/test": 1.471704125404358,
            "sparsity/test": 77.10059356689453,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.8149585127830505,
            "loss/test": 0.702557384967804,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}


results["HOTA"][2] = {
    "CIFAR100": [
        {
            "acc/test": 0.7411999702453613,
            "loss/test": 0.9376423954963684,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.508865237236023,
            "loss/test": 1.8005692958831787,
            "sparsity/test": 77.10059356689453,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.8922222256660461,
            "loss/test": 0.372340589761734,
            "sparsity/test": 77.10125732421875,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.7592240571975708,
            "loss/test": 0.8456394672393799,
            "sparsity/test": 77.10103607177734,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9807000160217285,
            "loss/test": 0.10697080940008163,
            "sparsity/test": 77.10089874267578,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.7377777695655823,
            "loss/test": 0.8293798565864563,
            "sparsity/test": 77.10059356689453,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.886716365814209,
            "loss/test": 0.42112603783607483,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["HOTA"][4] = {
    "CIFAR100": [
        {
            "acc/test": 0.753000020980835,
            "loss/test": 0.9272052645683289,
            "sparsity/test": 77.10091400146484,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.5505319237709045,
            "loss/test": 1.6237058639526367,
            "sparsity/test": 77.1006851196289,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.9526851773262024,
            "loss/test": 0.15636390447616577,
            "sparsity/test": 77.10126495361328,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.8998416662216187,
            "loss/test": 0.40223684906959534,
            "sparsity/test": 77.10104370117188,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.991599977016449,
            "loss/test": 0.04821410030126572,
            "sparsity/test": 77.10091400146484,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.8226984143257141,
            "loss/test": 0.5916779041290283,
            "sparsity/test": 77.1006088256836,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.9424554109573364,
            "loss/test": 0.22650344669818878,
            "sparsity/test": 77.10131072998047,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["HOTA"][7] = {
    "CIFAR100": [
        {
            "acc/test": 0.7721999883651733,
            "loss/test": 0.8617363572120667,
            "sparsity/test": 77.1009292602539,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.5815602540969849,
            "loss/test": 1.5043905973434448,
            "sparsity/test": 77.10073852539062,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.9789814949035645,
            "loss/test": 0.06920813024044037,
            "sparsity/test": 77.10126495361328,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.9566112160682678,
            "loss/test": 0.1848583072423935,
            "sparsity/test": 77.10105895996094,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9932000041007996,
            "loss/test": 0.03848518431186676,
            "sparsity/test": 77.1009292602539,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.8717460036277771,
            "loss/test": 0.43086087703704834,
            "sparsity/test": 77.10063171386719,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.9537492394447327,
            "loss/test": 0.18507838249206543,
            "sparsity/test": 77.101318359375,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}
results["HOTA"][10] = {
    "CIFAR100": [
        {
            "acc/test": 0.7878999710083008,
            "loss/test": 0.8314614295959473,
            "sparsity/test": 77.1009292602539,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "DTD": [
        {
            "acc/test": 0.609929084777832,
            "loss/test": 1.4296658039093018,
            "sparsity/test": 77.10074615478516,
            "sparsity percentile": 0.09999997168779373,
        }
    ],
    "EuroSAT": [
        {
            "acc/test": 0.9840278029441833,
            "loss/test": 0.05187156796455383,
            "sparsity/test": 77.10126495361328,
            "sparsity percentile": 0.0999993234872818,
        }
    ],
    "GTSRB": [
        {
            "acc/test": 0.9700712561607361,
            "loss/test": 0.1274917870759964,
            "sparsity/test": 77.10105895996094,
            "sparsity percentile": 0.09999991953372955,
        }
    ],
    "MNIST": [
        {
            "acc/test": 0.9937000274658203,
            "loss/test": 0.03449296951293945,
            "sparsity/test": 77.1009292602539,
            "sparsity percentile": 0.10000026226043701,
        }
    ],
    "RESISC45": [
        {
            "acc/test": 0.8876190185546875,
            "loss/test": 0.3939056694507599,
            "sparsity/test": 77.10063934326172,
            "sparsity percentile": 0.10000019520521164,
        }
    ],
    "SVHN": [
        {
            "acc/test": 0.9644284248352051,
            "loss/test": 0.15587253868579865,
            "sparsity/test": 77.101318359375,
            "sparsity percentile": 0.09999918192625046,
        }
    ],
}

# %%
## remove everything except acc/test

for approach in approaches:
    for order in orders:
        for dataset in results[approach][order]:
            results[approach][order][dataset] = results[approach][order][dataset][0]["acc/test"]

# %%
results

# %%
header = "&\t & \t" + " \t&\t ".join(datasets) + " \t&\t " + "average" + "\\\\\n \midrule \n"

# %%
header

# %%
print(header)

# %%
table = header

# %%
for order in orders:
    print(f"Order: {order}")

    order_rows = r"\parbox[t]{4mm}{\multirow{4}{*}{ \rotatebox[origin=c]{90}{$k=2$}}}"
    for approach in approaches:
        row = ""
        print(f"\tApproach: {approach}")
        row += f"&\t\\texttt{{{approach}}}"
        for dataset in datasets:
            row += f"\t&\t{results[approach][order][dataset]:.2f}"

        avg = sum(results[approach][order].values()) / len(datasets)

        row += f"\t& \t{avg:.2f}\t\\\\\n"
        order_rows += row

    order_rows += "\\midrule\n"
    table += order_rows

# %%
print(table)
